# %%
print('Hello World!')
# Out:
# Hello World!

# %%
import cv2

# %%
from matplotlib import pyplot as plt

# %%
img = cv2.imread('/Users\laksh\OneDrive\Pictures\FB_IMG_1483023883211.jpg')

# %%
plt.imshow(img)

# %%
meme1=cv2.imwrite('meme.jpg',img)

# %%
cv2.imshow('meme',img)
cv2.waitKey(0)

cv2.destroyAllWindows()

# %%
gray_img= cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)

# %%
cv2.imshow('gray_meme',gray_img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
ret, bw=cv2.threshold(gray_img,127,255,cv2.THRESH_BINARY)

# %%
cv2.imshow('binary image',bw)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
advth = cv2.adaptiveThreshold(img,255,cv2.ADAPTIVE_THRESH_MEAN_C,\cv2.THRESH_BINARY,11,2)
# Out:
#   File "<ipython-input-39-c2749c1c248f>", line 1
#     th2 = cv2.adaptiveThreshold(img,255,cv2.ADAPTIVE_THRESH_MEAN_C,\cv2.THRESH_BINARY,11,2)
#                                                                                            ^
# SyntaxError: unexpected character after line continuation character

# %%
advth3= cv2.adaptiveThreshold(img,255,cv2.ADAPTIVE_THRESH_GAUSSIAN_C, \cv2.THRESH_BINARY,11,2)
